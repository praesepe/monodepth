# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.utils.data as data
import matplotlib.pyplot as plt
import numpy as np
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import math
import argparse
import skimage.transform
from tensorboardX import SummaryWriter
import random
import os
import os.path
import matplotlib.image as mpimg
from PIL import Image
import import_ipynb
from MonodepthModel import *
import scipy.misc
import hdf5storage
from IPython.display import clear_output
from flow_warp.Optical_Flow_Warping_Tensorflow.flownet2_pytorch.networks.submodules import *
from flow_warp.Optical_Flow_Warping_Tensorflow.flownet2_pytorch.networks.resample2d_package.modules.resample2d import Resample2d
os.environ['TF_CPP_MIN_LOG_LEVEL']='1'

torch.cuda.set_device(1)

# %%
test = Image.open('/eva_data/hylai_model/dataset/play_for_benchmark/train/img/056/056_00626.png').convert('RGB')
#plt.imshow(test)
print(np.array(test).shape)
test = transforms.ToTensor()(test).unsqueeze(0)
import scipy.io as sio
d = sio.loadmat('/eva_data/hylai_model/dataset/play_for_benchmark/train/flow/056/056_00625.mat')
print(type(d))
print(d['u'])
plt.imshow(d['u'])
flow = np.concatenate((np.expand_dims(d['u'], 2), np.expand_dims(d['v'], 2), np.zeros((1080,1920,1))), axis = 2)
print(flow.shape, "haha")
flow = np.transpose(np.resize(flow, (1, 1080, 1920, 3)), [0,3,1,2])
#plt.imshow(flow[0,0,:,:])
result = Resample2d()(Variable(test.cuda()), Variable(torch.from_numpy(flow)).cuda())
print(result.shape)
out = result.squeeze(0).data.cpu().numpy().transpose((1,2,0))
#plt.imshow(out)
# Out:
# (1080, 1920, 3)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-3b453304fcb0> in <module>()
#       4 test = transforms.ToTensor()(test).unsqueeze(0)
#       5 import scipy.io as sio
# ----> 6 d = sio.loadmat('/eva_data/hylai_model/dataset/play_for_benchmark/train/flow/056/056_00625.mat')
#       7 print(type(d))
#       8 print(d['u'])
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     140     variable_names = kwargs.pop('variable_names', None)
#     141     MR, file_opened = mat_reader_factory(file_name, appendmat, **kwargs)
# --> 142     matfile_dict = MR.get_variables(variable_names)
#     143     if mdict is not None:
#     144         mdict.update(matfile_dict)
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/io/matlab/mio5.py in get_variables(self, variable_names)
#     270         mdict['__globals__'] = []
#     271         while not self.end_of_stream():
# --> 272             hdr, next_position = self.read_var_header()
#     273             name = asstr(hdr.name)
#     274             if name in mdict:
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/io/matlab/mio5.py in read_var_header(self)
#     215            position in stream of next variable
#     216         '''
# --> 217         mdtype, byte_count = self._file_reader.read_full_tag()
#     218         if not byte_count > 0:
#     219             raise ValueError("Did not read any bytes")
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.read_full_tag()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.cread_full_tag()
#
# streams.pyx in scipy.io.matlab.streams.GenericStream.read_into()
#
# OSError: could not read bytes

# %%
test = Image.open('/eva_data/hylai_model/dataset/play_for_benchmark/train/img/001/001_00060.png').convert('RGB')
plt.imshow(test)

# %%
def get_args():
    parser = argparse.ArgumentParser(description='Monodepth PyTorch implementation.')
    
    parser.add_argument('--mode',                      type=str,   help='train or test', default='train')
    parser.add_argument('--model_name',                type=str,   help='model name', default='monodepth')
    parser.add_argument('--encoder',                   type=str,   help='type of encoder, vgg or resnet50', default='vgg')
    parser.add_argument('--dataset',                   type=str,   help='dataset to train on, kitti, or cityscapes', default='kitti')
    parser.add_argument('--data_path',                 type=str,   help='path to the data', required=True)
    parser.add_argument('--filenames_file',            type=str,   help='path to the filenames text file', required=True)
    parser.add_argument('--input_height',              type=int,   help='input height', default=256)
    parser.add_argument('--input_width',               type=int,   help='input width', default=512)
    parser.add_argument('--batch_size',                type=int,   help='batch size', default=8)
    parser.add_argument('--num_epochs',                type=int,   help='number of epochs', default=50)
    parser.add_argument('--learning_rate',             type=float, help='initial learning rate', default=1e-4)
    parser.add_argument('--lr_loss_weight',            type=float, help='left-right consistency weight', default=1.0)
    parser.add_argument('--alpha_image_loss',          type=float, help='weight between SSIM and L1 in the image loss', default=0.85)
    parser.add_argument('--disp_gradient_loss_weight', type=float, help='disparity smoothness weigth', default=0.1)
    parser.add_argument('--do_stereo',                             help='if set, will train the stereo model', action='store_true')
    parser.add_argument('--wrap_mode',                 type=str,   help='bilinear sampler wrap mode, edge or border', default='border')
    parser.add_argument('--use_deconv',                            help='if set, will use transposed convolutions', action='store_true')
    parser.add_argument('--num_gpus',                  type=int,   help='number of GPUs to use for training', default=1)
    parser.add_argument('--num_threads',               type=int,   help='number of threads to use for data loading', default=8)
    parser.add_argument('--output_directory',          type=str,   help='output directory for test disparities, if empty outputs to checkpoint folder', default='')
    parser.add_argument('--log_directory',             type=str,   help='directory to save checkpoints and summaries', default='')
    parser.add_argument('--checkpoint_path',           type=str,   help='path to a specific checkpoint to load', default='')
    parser.add_argument('--retrain',                               help='if used with checkpoint_path, will restart training from step zero', action='store_true')
    parser.add_argument('--full_summary',                          help='if set, will keep more data for each summary. Warning: the file can become very large', action='store_true')
    
    args = parser.parse_args()
    return args

# %%
#args = get_args()
#net = MonodepthNet().cuda()
#net = torch.load("/home/hylai/monodepth/model_city2kitti")
#net = torch.load("/eva_data/hylai_model/new_lr_grad_model/model_epoch45")
net = torch.load("/eva_data/hylai_model/kitti_flow_supervised_syn_44/model_epoch20", map_location={'cuda:0':'cuda:1'})
optimizer = optim.Adam(net.parameters(), lr=1e-4)
params = list(net.parameters())
name = list(net.named_parameters())

# %%
def get_data(path = '/eva_data/hylai_model/my/output/folder/'):
    path2 = '/eva_data/hylai_model/dataset/kitti/'
    file_path_train = '/home/hylai/monodepth/utils/filenames/kitti_train_files.txt'
    file_path_test = '/home/hylai/monodepth/utils/filenames/eigen_test_files.txt'
    #file_path_flow_train = '/home/hylai/monodepth/utils/filenames/kitti_total_flow_train_files.txt'
    f_train = open(file_path_train)
    f_test = open(file_path_test)
    #f_flow_train = open(file_path_flow_train)
    left_image_train = list()
    right_image_train = list()
    left_image_test = list()
    right_image_test = list()
    
    num_train = 0
    num_test = 0
    
    for line in f_train:
        num_train += 1
        left_image_train.append(path+line.split()[0])
        right_image_train.append(path+line.split()[1])
    for line in f_test:
        num_test += 1
        left_image_test.append(path+line.split()[0])
        right_image_test.append(path+line.split()[1])
        
    return left_image_train, right_image_train, left_image_test, right_image_test, num_train, num_test

# %%
def get_cs_data(path_right = '/eva_data/hylai_model/dataset/cityscape/rightImg8bit/train_extra/'):
    path_left = '/eva_data/hylai_model/dataset/cityscape/leftImg8bit/train_extra/'
    file_path_train = '/home/hylai/monodepth/utils/filenames/cityscapes_train_files.txt'
    file_path_test = '/home/hylai/monodepth/utils/filenames/cityscapes_test_files.txt'
    f_train = open(file_path_train)
    f_test = open(file_path_test)
    left_image_train = list()
    right_image_train = list()
    left_image_test = list()
    right_image_test = list()
    
    num_train = 0
    num_test = 0
    
    for line in f_train:
        num_train += 1
        left_image_train.append(path_left+line.split()[0])
        right_image_train.append(path_right+line.split()[1])
    for line in f_test:
        num_test += 1
        left_image_test.append(path_left+line.split()[0])
        right_image_test.append(path_right+line.split()[1])
        
    return left_image_train, right_image_train, left_image_test, right_image_test, num_train, num_test

# %%
def get_flow_data(path = '/eva_data/hylai_model/dataset/kitti2/'):
    path2 = '/eva_data/hylai_model/dataset/kitti/'
    file_path_train = '/home/hylai/monodepth/utils/filenames/kitti_total_flow_train_files.txt'
    #file_path_train = '/home/hylai/monodepth/utils/filenames/kitti_flow_train_files.txt'
    file_path_test = '/home/hylai/monodepth/utils/filenames/kitti_flow_test_files.txt'
    f_train = open(file_path_train)
    f_test = open(file_path_test)
    former_image_train = list()
    latter_image_train = list()
    #flow_train = list()
    former_image_test = list()
    latter_image_test = list()
    
    num_train = 0
    num_test = 0
    
    for line in f_train:
        num_train += 1
        former_image_train.append(path+line.split()[0])
        latter_image_train.append(path+line.split()[1])
        #flow_train.append(path+line.split()[2])
    for line in f_test:
        num_test += 1
        former_image_test.append(path+line.split()[0])
        latter_image_test.append(path+line.split()[1])
        
    return former_image_train, latter_image_train, former_image_test, latter_image_test

# %%
def get_transform():
    return transforms.Compose([
        transforms.Scale([512, 256]),
        transforms.ToTensor()
    ])

# %%
class myImageFolder(data.Dataset):
    def __init__(self, left, right, training, flow = None):
        self.right = right
        self.left = left
        self.training = training
        self.flow = flow
        
    def __getitem__(self, index):
        left = self.left[index]
        right = self.right[index]
        left_image = Image.open(left).convert('RGB')
        right_image = Image.open(right).convert('RGB')
        
        if self.flow is not None:
            flow = self.flow[index]
            flow_image = Image.open(flow).convert('RGB')
        
        #augmentation
        if self.training:
            
            #randomly flip
            """
            if random.uniform(0, 1) > 0.5:
                left_image = left_image.transpose(Image.FLIP_LEFT_RIGHT)
                right_image = right_image.transpose(Image.FLIP_LEFT_RIGHT)
                if self.flow is not None:
                    flow_image = flow_image.transpose(Image.FLIP_LEFT_RIGHT)
            """
                
            #randomly shift gamma
            if random.uniform(0, 1) > 0.5:
                gamma = random.uniform(0.8, 1.2)
                left_image = Image.fromarray(np.clip((np.array(left_image) ** gamma), 0, 255).astype('uint8'), 'RGB')
                right_image = Image.fromarray(np.clip((np.array(right_image) ** gamma), 0, 255).astype('uint8'), 'RGB')
            
            #randomly shift brightness
            if random.uniform(0, 1) > 0.5:
                brightness = random.uniform(0.5, 2.0)
                left_image = Image.fromarray(np.clip((np.array(left_image) * brightness), 0, 255).astype('uint8'), 'RGB')
                right_image = Image.fromarray(np.clip((np.array(right_image) * brightness), 0, 255).astype('uint8'), 'RGB')
            
            #randomly shift color
            if random.uniform(0, 1) > 0.5:
                colors = [random.uniform(0.8, 1.2) for i in range(3)]
                shape = np.array(left_image).shape
                white = np.ones((shape[0], shape[1]))
                color_image = np.stack([white * colors[i] for i in range(3)], axis=2)
                left_image = Image.fromarray(np.clip((np.array(left_image) * color_image), 0, 255).astype('uint8'), 'RGB')
                right_image = Image.fromarray(np.clip((np.array(right_image) * color_image), 0, 255).astype('uint8'), 'RGB')
                
        
        #transforms
        process = get_transform()
        left_image = process(left_image)
        right_image = process(right_image)
        
        if self.flow is not None:
            flow_image = process(flow_image)
            flow_image[0,:,:] = - (flow_image[0,:,:] - 0.5) * flow_image.shape[2]
            flow_image[1,:,:] = (flow_image[1,:,:] - 0.5) * flow_image.shape[1]
            return left_image, right_image, flow_image
        
        return left_image, right_image
    def __len__(self):
        return len(self.left)

# %%
def make_pyramid(image, num_scales):
    scale_image = [Variable(image.cuda())]
    height, width = image.shape[2:]

    for i in range(num_scales - 1):
        new = []
        for j in range(image.shape[0]):
            ratio = 2 ** (i+1)
            nh = height // ratio
            nw = width // ratio
            tmp = transforms.ToPILImage()(image[j]).convert('RGB')
            tmp = transforms.Scale([nw, nh])(tmp)
            tmp = transforms.ToTensor()(tmp)
            new.append(tmp.unsqueeze(0))
        this = torch.cat((i for i in new), 0)
        scale_image.append(Variable(this.cuda()))
        
    return scale_image

# %%
def gradient_x(img):
    gx = torch.add(img[:,:,:-1,:], -1, img[:,:,1:,:])
    return gx

def gradient_y(img):
    gy = torch.add(img[:,:,:,:-1], -1, img[:,:,:,1:])
    return gy

def get_disparity_smoothness(disp, pyramid):
    disp_gradients_x = [gradient_x(d) for d in disp]
    disp_gradients_y = [gradient_y(d) for d in disp]

    image_gradients_x = [gradient_x(img) for img in pyramid]
    image_gradients_y = [gradient_y(img) for img in pyramid]
    
    weights_x = [torch.exp(-torch.mean(torch.abs(g), 1, keepdim=True)) for g in image_gradients_x]
    weights_y = [torch.exp(-torch.mean(torch.abs(g), 1, keepdim=True)) for g in image_gradients_y]
    
    smoothness_x = [disp_gradients_x[i] * weights_x[i] for i in range(4)]
    smoothness_y = [disp_gradients_y[i] * weights_y[i] for i in range(4)]
    
    return smoothness_x + smoothness_y

# %%
def SSIM(x, y):
    C1 = 0.01 ** 2
    C2 = 0.03 ** 2
    
    mu_x = F.avg_pool2d(x, 3, 1, 0)
    mu_y = F.avg_pool2d(y, 3, 1, 0)
    
    #(input, kernel, stride, padding)
    sigma_x  = F.avg_pool2d(x ** 2, 3, 1, 0) - mu_x ** 2
    sigma_y  = F.avg_pool2d(y ** 2, 3, 1, 0) - mu_y ** 2
    sigma_xy = F.avg_pool2d(x * y , 3, 1, 0) - mu_x * mu_y
    
    SSIM_n = (2 * mu_x * mu_y + C1) * (2 * sigma_xy + C2)
    SSIM_d = (mu_x ** 2 + mu_y ** 2 + C1) * (sigma_x + sigma_y + C2)
    
    SSIM = SSIM_n / SSIM_d
    
    return torch.clamp((1 - SSIM) / 2, 0, 1)

# %%
def post_process_disparity(disp):
    _, h, w = disp.shape
    l_disp = -disp[0,:,:]
    r_disp = np.fliplr(disp[1,:,:])
    m_disp = 0.5 * (l_disp + r_disp)
    l, _ = np.meshgrid(np.linspace(0, 1, w), np.linspace(0, 1, h))
    l_mask = 1.0 - np.clip(20 * (l - 0.05), 0, 1)
    r_mask = np.fliplr(l_mask)
    return r_mask * l_disp + l_mask * r_disp + (1.0 - l_mask - r_mask) * m_disp

# %%
left_image_train, right_image_train, left_image_test, right_image_test, num_train, num_test = get_data()
TrainImageLoader = torch.utils.data.DataLoader(
         myImageFolder(left_image_train, right_image_train, True), 
         batch_size = 6, shuffle = True, num_workers = 8, drop_last =False)
TestImageLoader = torch.utils.data.DataLoader(
         myImageFolder(left_image_test, right_image_test, False),
         batch_size = 1, shuffle = False, num_workers = 1, drop_last =False)

former_train, latter_train, former_test, latter_test = get_flow_data()
TrainFlowLoader = torch.utils.data.DataLoader(
         myImageFolder(former_train, latter_train, True), 
         batch_size = 2, shuffle = True, num_workers = 8, drop_last =False)
TestFlowLoader = torch.utils.data.DataLoader(
         myImageFolder(former_test, latter_test, False),
         batch_size = 1, shuffle = False, num_workers = 8, drop_last =False)

#Train
do_stereo = 1
alpha_image_loss = 0.85
disp_gradient_loss_weight = 0.1
lr_loss_weight = 1.0
num_epochs = 50
optimizer = optim.Adam(net.parameters(), lr = 0.0001)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[np.int32((3/5) * num_epochs), np.int32((4/5) * num_epochs)], gamma=0.5)

# %%
for epoch in range(1, 51):
    scheduler.step()
    for batch_idx, ((left, right), (former, latter)) in enumerate(zip(TrainImageLoader, TrainFlowLoader), 0):
        print(epoch, batch_idx)

        optimizer.zero_grad()
        
        left = torch.cat((left, former), 0)
        right = torch.cat((right, latter), 0)
        
        #generate image pyramid[scale][batch]
        left_pyramid = make_pyramid(left, 4)
        right_pyramid = make_pyramid(right, 4)
        
        if do_stereo:
            model_input = Variable(torch.cat((left, right), 1).cuda())
        else:
            model_input = Variable(left.cuda())
        
        disp_est_scale, disp_est = net(model_input)
        left_est = [Resample2d()(right_pyramid[i], disp_est_scale[i]) for i in range(4)]

        disp_left_smoothness = get_disparity_smoothness(disp_est, left_pyramid)
        l1_left = [torch.abs(left_est[i] - left_pyramid[i]) for i in range(4)]
        l1_reconstruction_loss_left = [torch.mean(l) for l in l1_left]
        ssim_left = [SSIM(left_est[i], left_pyramid[i]) for i in range(4)]
        ssim_loss_left = [torch.mean(s) for s in ssim_left]
        image_loss_left  = [alpha_image_loss * ssim_loss_left[i]  + (1 - alpha_image_loss) * l1_reconstruction_loss_left[i]  for i in range(4)]
        image_loss = image_loss_left[0] + image_loss_left[1] + image_loss_left[2] + image_loss_left[3]
        disp_left_loss  = [torch.mean(torch.abs(disp_left_smoothness[i]))  / 2 ** i for i in range(4)]
        disp_gradient_loss = disp_left_loss[0] + disp_left_loss[1] + disp_left_loss[2] + disp_left_loss[3]
        
        total_loss = image_loss + disp_gradient_loss_weight * disp_gradient_loss# + lr_loss_weight * lr_loss
        

        model_input_2 = Variable(torch.cat((right, left), 1).cuda())
        disp_est_scale_2, disp_est_2 = net(model_input_2)
        right_est = [Resample2d()(left_pyramid[i], disp_est_scale_2[i]) for i in range(4)]

        disp_right_smoothness = get_disparity_smoothness(disp_est_2, right_pyramid)
        l1_right = [torch.abs(right_est[i] - right_pyramid[i]) for i in range(4)]
        l1_reconstruction_loss_right = [torch.mean(l) for l in l1_right]
        ssim_right = [SSIM(right_est[i], right_pyramid[i]) for i in range(4)]
        ssim_loss_right = [torch.mean(s) for s in ssim_right]
        image_loss_right  = [alpha_image_loss * ssim_loss_right[i]  + (1 - alpha_image_loss) * l1_reconstruction_loss_right[i]  for i in range(4)]
        image_loss_2 = image_loss_right[0] + image_loss_right[1] + image_loss_right[2] + image_loss_right[3]
        disp_right_loss  = [torch.mean(torch.abs(disp_right_smoothness[i]))  / 2 ** i for i in range(4)]
        disp_gradient_loss_2 = disp_right_loss[0] + disp_right_loss[1] + disp_right_loss[2] + disp_right_loss[3]
        
        #LR consistency
        right_to_left_disp = [- Resample2d()(disp_est_2[i], disp_est_scale[i]) for i in range(4)]
        left_to_right_disp = [- Resample2d()(disp_est[i], disp_est_scale_2[i]) for i in range(4)]
        
        #LR consistency
        lr_left_loss  = [torch.mean(torch.abs(right_to_left_disp[i] - disp_est[i]))  for i in range(4)]
        lr_right_loss = [torch.mean(torch.abs(left_to_right_disp[i] - disp_est_2[i])) for i in range(4)]
        lr_loss = sum(lr_left_loss + lr_right_loss)
        
        #Total loss
        total_loss_2 = image_loss_2 + disp_gradient_loss_weight * disp_gradient_loss_2# + lr_loss_weight * lr_loss
        total = total_loss_2 + total_loss + lr_loss_weight * lr_loss
        total.backward()
        print(total)
        print(net.conv1.weight.grad[0,0,0,0])
        optimizer.step()

        if batch_idx % 100 == 0:
            clear_output()
    if epoch % 5 == 0:
        torch.save(net, "/eva_data/hylai_model/kitti_flow_unsupervised_sample/model_epoch" + str(epoch))
# Out:
# 36 2901
# Variable containing:
#  0.2510
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   2.3253
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2902
# Variable containing:
#  0.2363
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -3.3188
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2903
# Variable containing:
#  0.3285
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -5.4916
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2904
# Variable containing:
#  0.2652
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-05 *
#   1.6401
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2905
# Variable containing:
#  0.2924
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   2.4591
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2906
# Variable containing:
#  0.2317
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -9.4726
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2907
# Variable containing:
#  0.2679
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -3.7478
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2908
# Variable containing:
#  0.2560
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-05 *
#   3.2693
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2909
# Variable containing:
#  0.2760
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   6.0269
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2910
# Variable containing:
#  0.2671
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   6.0113
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2911
# Variable containing:
#  0.3587
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-05 *
#   4.5256
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2912
# Variable containing:
#  0.2628
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   1.2545
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2913
# Variable containing:
#  0.2655
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   2.6799
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2914
# Variable containing:
#  0.2566
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   9.8280
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2915
# Variable containing:
#  0.1983
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -3.5916
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2916
# Variable containing:
#  0.3113
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -1.1393
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2917
# Variable containing:
#  0.2299
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -5.2239
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2918
# Variable containing:
#  0.2090
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -6.3977
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2919
# Variable containing:
#  0.2365
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -4.4487
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2920
# Variable containing:
#  0.3113
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -2.5245
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2921
# Variable containing:
#  0.2679
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   5.6173
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2922
# Variable containing:
#  0.2770
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -5.8534
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2923
# Variable containing:
#  0.2847
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -1.6364
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2924
# Variable containing:
#  0.3545
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-06 *
#  -2.8322
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2925
# Variable containing:
#  0.2360
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   9.8274
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2926
# Variable containing:
#  0.2589
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -2.1932
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2927
# Variable containing:
#  0.2377
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -2.1877
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2928
# Variable containing:
#  0.3185
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   1.5411
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2929
# Variable containing:
#  0.2412
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-03 *
#   1.1025
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2930
# Variable containing:
#  0.3465
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   1.9430
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2931
# Variable containing:
#  0.3139
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-05 *
#  -1.4200
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2932
# Variable containing:
#  0.2872
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -9.5943
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2933
# Variable containing:
#  0.2645
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -4.3612
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2934
# Variable containing:
#  0.2810
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   1.8931
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2935
# Variable containing:
#  0.2746
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -2.3763
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2936
# Variable containing:
#  0.2796
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   1.7939
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2937
# Variable containing:
#  0.2642
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -1.9857
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2938
# Variable containing:
#  0.1976
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   2.0384
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2939
# Variable containing:
#  0.2180
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -1.3102
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2940
# Variable containing:
#  0.4800
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-03 *
#  -1.1149
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2941
# Variable containing:
#  0.2743
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -4.5832
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2942
# Variable containing:
#  0.2625
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -2.9366
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2943
# Variable containing:
#  0.2847
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   9.4288
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2944
# Variable containing:
#  0.3448
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   4.4314
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2945
# Variable containing:
#  0.3099
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   2.6448
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2946
# Variable containing:
#  0.2572
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   2.5540
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2947
# Variable containing:
#  0.2422
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   3.6139
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2948
# Variable containing:
#  0.3171
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-05 *
#  -6.7229
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2949
# Variable containing:
#  0.2846
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-05 *
#   7.3525
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2950
# Variable containing:
#  0.3358
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-05 *
#  -8.9267
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2951
# Variable containing:
#  0.2897
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   5.3826
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2952
# Variable containing:
#  0.2928
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   5.3378
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2953
# Variable containing:
#  0.3261
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-05 *
#   5.2360
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2954
# Variable containing:
#  0.2945
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -1.7971
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2955
# Variable containing:
#  0.2947
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   3.4172
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2956
# Variable containing:
#  0.2970
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -4.0132
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2957
# Variable containing:
#  0.2764
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   2.0082
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2958
# Variable containing:
#  0.2879
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -1.3168
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2959
# Variable containing:
#  0.3341
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   1.1331
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2960
# Variable containing:
#  0.2766
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -2.5906
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2961
# Variable containing:
#  0.3003
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -5.3324
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2962
# Variable containing:
#  0.3017
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   4.1079
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2963
# Variable containing:
#  0.2849
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-05 *
#   1.5328
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2964
# Variable containing:
#  0.3211
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-05 *
#   4.4190
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2965
# Variable containing:
#  0.2343
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   1.1799
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2966
# Variable containing:
#  0.3182
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -1.9265
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2967
# Variable containing:
#  0.2641
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -4.5277
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2968
# Variable containing:
#  0.2697
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -6.1550
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2969
# Variable containing:
#  0.3075
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -6.7572
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2970
# Variable containing:
#  0.2730
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   2.4989
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2971
# Variable containing:
#  0.2421
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   1.7038
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2972
# Variable containing:
#  0.3252
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -1.6912
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2973
# Variable containing:
#  0.3103
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   2.0635
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2974
# Variable containing:
#  0.2402
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   2.0819
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2975
# Variable containing:
#  0.2822
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   2.1130
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2976
# Variable containing:
#  0.3254
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   3.1216
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2977
# Variable containing:
#  0.2832
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-05 *
#  -9.1619
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2978
# Variable containing:
#  0.3056
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   2.7146
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2979
# Variable containing:
#  0.2348
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-06 *
#   6.9217
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2980
# Variable containing:
#  0.2501
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   2.8593
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2981
# Variable containing:
#  0.2384
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-05 *
#   2.8009
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2982
# Variable containing:
#  0.2628
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-05 *
#  -4.3148
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2983
# Variable containing:
#  0.3546
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   7.3864
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2984
# Variable containing:
#  0.3707
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   6.9189
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2985
# Variable containing:
#  0.2890
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -4.4886
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2986
# Variable containing:
#  0.2683
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -3.8456
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2987
# Variable containing:
#  0.2991
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -5.8820
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2988
# Variable containing:
#  0.2859
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -2.7025
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2989
# Variable containing:
#  0.2774
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -8.9096
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2990
# Variable containing:
#  0.3037
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   8.6858
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2991
# Variable containing:
#  0.3788
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -1.0959
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2992
# Variable containing:
#  0.2801
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -4.9103
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2993
# Variable containing:
#  0.2351
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#  -5.7965
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2994
# Variable containing:
#  0.3511
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# Variable containing:
# 1.00000e-04 *
#   4.2550
# [torch.cuda.FloatTensor of size 1 (GPU 1)]
#
# 36 2995
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#import png
#net = torch.load("/eva_data/hylai_model/cs_lr_crop_model/model_epoch10", map_location={'cuda:2':'cuda:1'})
net = torch.load("/eva_data/hylai_model/kitti_flow_supervised_sample_44/model_epoch50", map_location={'cuda:2':'cuda:1'})
disparities = np.zeros((697, 256, 512), dtype=np.float32)
disparities_pp = np.zeros((697, 256, 512), dtype=np.float32)
#resolution = [[375,1242]]*155+[[370,1224]]*2+[[374,1238]]*13+[[376,1241]]*30
for batch_idx, (left, right) in enumerate(TrainFlowLoader, 0):
    print(batch_idx)
    #plt.imshow(np.flip(right.numpy()[0,0,:,:], 1))
    #model_input = Variable(torch.cat((right, left), 1).cuda())
    left_batch = torch.cat((left, torch.from_numpy(np.flip(left.numpy(), 3).copy())), 0)
    right_batch = torch.cat((right, torch.from_numpy(np.flip(right.numpy(), 3).copy())), 0)
    model_input = Variable(torch.cat((left_batch, right_batch), 1).cuda())
    #model_input = Variable(left.cuda())
    disp_est_scale, disp_est = net(model_input)
    disparities[batch_idx] = -disp_est[0][0,0,:,:].data.cpu().numpy()
    plt.imshow(disp_est_scale[0][0,0,:,:].data.cpu().numpy())
    disp_pp = post_process_disparity(-disp_est[0][:,0,:,:].data.cpu().numpy())
    disparities_pp[batch_idx] = disp_pp
    plt.imshow(disp_pp)
    disp_to_img = scipy.misc.imresize(disp_pp, resolution[batch_idx]).astype('uint16')
    plt.imshow(disp_to_img)
    """
    with open('/eva_data/hylai_model/disp_0/'+"%06d"%batch_idx+'_10.png', 'wb') as f:
        writer = png.Writer(width=disp_to_img.shape[1], height=disp_to_img.shape[0], bitdepth=16, greyscale=True)
        zgray2list = (disp_to_img*256).tolist()
        writer.write(f, zgray2list)
    """
    if batch_idx == 10:
        break
#np.save('/home/hylai/monodepth/disparities.npy', disparities)
#np.save('/home/hylai/monodepth/disparities_pp.npy', disparities_pp)
# Out:
# 0
# 1
# 2
# 3
# /home/hylai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 4
# 5
# 6
# 7
# 8
# 9
# 10

# %%
image = scipy.misc.imread('/eva_data/hylai_model/dataset/kitti/training/flow_occ/000010_10.png')
print(image.min())
plt.imshow(image[:,:,0])
# Out:
# 0
# /home/hylai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
1. KITTI flow dataset is too small(200 pairs), CityScapes on request
2. flow loss function, some of pixels are 0, learning rate
3. left-right consistency

# %%
#test
import scipy.misc

input_image = scipy.misc.imread("./test.jpg", mode="RGB")
original_height, original_width, num_channels = input_image.shape
input_image = scipy.misc.imresize(input_image, [256, 512], interp='lanczos')
input_image = input_image.astype(np.float32) / 255
input_images = np.stack((input_image, np.fliplr(input_image)), 0)
model_input = Variable(torch.from_numpy(input_images.transpose((0,3,1,2))).cuda())
disp_est = net(model_input)

disp_pp = post_process_disparity(disp_est[0][:,0,:,:].data.cpu().numpy())
disp_to_img = scipy.misc.imresize(disp_pp, [original_height, original_width])
plt.imshow(disp_to_img)
plt.imsave("./myresult.png", disp_to_img, cmap='plasma')
#torch.save(net, "./model_city2kitti")
print(disp_to_img)
# Out:
# /home/hylai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.
# /home/hylai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-67-41fc4744889a> in <module>()
#       8 input_images = np.stack((input_image, np.fliplr(input_image)), 0)
#       9 model_input = Variable(torch.from_numpy(input_images.transpose((0,3,1,2))).cuda())
# ---> 10 disp_est = net(model_input)
#      11
#      12 disp_pp = post_process_disparity(disp_est[0][:,0,:,:].data.cpu().numpy())
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/monodepth/MonodepthModel.ipynb in forward(self, x)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     280     def forward(self, input):
#     281         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 282                         self.padding, self.dilation, self.groups)
#     283
#     284
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py in conv2d(input, weight, bias, stride, padding, dilation, groups)
#      88                 _pair(0), groups, torch.backends.cudnn.benchmark,
#      89                 torch.backends.cudnn.deterministic, torch.backends.cudnn.enabled)
# ---> 90     return f(input, weight, bias)
#      91
#      92
#
# RuntimeError: Given groups=1, weight[64, 6, 7, 7], so expected input[2, 3, 256, 512] to have 6 channels, but got 3 channels instead
